# %%
from langchain.llms import GooglePalm

api_key="AIzaSyBsUcB8YTAQjJJakKDqt2GZIVhTW1Gw0vg"
llm= GooglePalm(google_api_key=api_key,temperature=0.2)

poem = llm("write a poem on my love for dosa")
print(poem)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3 api_key="AIzaSyBsUcB8YTAQjJJakKDqt2GZIVhTW1Gw0vg"
#       4 llm= GooglePalm(google_api_key=api_key,temperature=0.2)
# ----> 6 poem = llm("write a poem on my love for dosa")
#       7 print(poem)
#
# File ~\anaconda\anaconda2024-2.1\Lib\site-packages\langchain\llms\base.py:825, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     818 if not isinstance(prompt, str):
#     819     raise ValueError(
#     820         "Argument `prompt` is expected to be a string. Instead found "
#     821         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#     822         "`generate` instead."
#     823     )
#     824 return (
# --> 825     self.generate(
#     826         [prompt],
#     827         stop=stop,
#     828         callbacks=callbacks,
# ...

# %%
from langchain.utilities import SQLDatabase
db_user="root"
db_password="@Clevc919"
db_host="localhost"
db_name="atliq_tshirts"
print(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")
db=SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")
print(db.table_info)
# Out:
# mysql+pymysql://root:@Clevc919@localhost/atliq_tshirts
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda\anaconda2024-2.1\Lib\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File ~\anaconda\anaconda2024-2.1\Lib\socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda\anaconda2024-2.1\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
from langchain_experimental.sql import SQLDatabaseChain

db_chain=SQLDatabaseChain(llm,db,verbose=True)
qns1=db_chain("How many t-shirts do we have left for nike in extra small size and white color?")

# %%
qns1

# %%
qns2 = db_chain_run("SELECT SUM(price*stock_quantity) FROM t_shirts WHERE size='S'") #few short learning because it can't understand price column
